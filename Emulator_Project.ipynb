# %% [markdown]
# <a href="https://colab.research.google.com/github/gladsonchala/1000-AI-collection-tools/blob/main/Emulator_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import pytz
from IPython.display import HTML

utc_now = datetime.datetime.utcnow()
addis_tz = pytz.timezone('Africa/Addis_Ababa')
addis_time = utc_now.astimezone(addis_tz)
formatted_time = addis_time.strftime("%I:%M %p")
now = formatted_time

emulator = f"""
<head>
  <title>Mobile Emulator</title>
  <!-- Include Bootstrap CSS -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" />

  <!-- Bootstrap Font Icon CSS -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" />
  <style>
    body{{
      background-color: #020202;
    }}
    /* Style the mobile emulator */
    .mobile {{
      width: 375px; /* Set the width of the mobile screen */
      height: 667px; /* Set the height of the mobile screen */
      background-color: #f2f2f2; /* Set the background color */
      border: 2px solid #ccc; /* Set a border around the mobile */
      border-radius: 20px; /* Rounded corners */
      margin: 0 auto; /* Center the mobile emulator */
      padding-top: 20px;
      overflow: hidden; /* Hide overflow content */
      position: relative; /* Position relative for absolute positioning of status bar */
    }}

    /* Style the icons */
    .icon {{
      width: 50px; /* Set the width of the icons */
      height: 50px; /* Set the height of the icons */
      background-color: #fff; /* Set the background color */
      border: 1px solid #ccc; /* Set a border around the icons */
      border-radius: 10px; /* Rounded corners */
      margin: 20px; /* Add margin around the icons */
      float: left; /* Float the icons to the left */
      text-align: center; /* Center the icon */
      line-height: 50px; /* Vertically center the icon */
      cursor: pointer; /* Change cursor to pointer on hover */
      transition: transform 0.3s ease; /* Smooth transition effect */
      -webkit-text-stroke: 0.5px;
    }}

    /* Style different colors for icons */
    .icon:nth-child(odd) {{
      background-color: #ff6347; /* Coral */
    }}
    .icon:nth-child(even) {{
      background-color: #00ced1; /* Dark Turquoise */
    }}

    /* Scale animation on hover */
    .icon:hover {{
      transform: scale(1.1); /* Scale the icon by 10% on hover */
    }}

    /* Style the status bar */
    .status-bar {{
      position: absolute; /* Position absolute to place it on top */
      top: 0; /* Align to the top */
      left: 0; /* Align to the left */
      width: 100%; /* Full width */
      height: 24px; /* Height of the status bar */
      background-color: #000; /* Black background color */
      color: #fff; /* White text color */
      display: flex; /* Flex layout for alignment */
      justify-content: space-between; /* Space between elements */
      align-items: center; /* Center vertically */
      padding: 0 10px; /* Padding */
      font-size: 12px; /* Font size */
      margin-bottom: 40px;
    }}

    /* Style the network icon */
    .network-icon {{
      font-size: 18px; /* Larger font size for icon */
      margin-right: 5px; /* Margin between icon and text */
    }}

    /* Style the battery icon */
    .battery-icon {{
      margin-right: 5px; /* Margin between icon and text */
    }}

    /* Style the navigation buttons */
    .navigation-buttons {{
      position: absolute; /* Position absolute to place it at the bottom */
      bottom: 0; /* Align to the bottom */
      left: 0; /* Align to the left */
      width: 100%; /* Full width */
      background-color: #000; /* Black background color */
      display: flex; /* Flex layout for alignment */
      justify-content: center; /* Space between buttons */
      padding: 10px; /* Padding */
      box-sizing: border-box; /* Include padding in width calculation */
    }}

    /* Style the navigation button icons */
    .navigation-buttons button {{
      background-color: transparent; /* Transparent background */
      border: none; /* No border */
      color: #fff; /* White text color */
      font-size: 22px; /* Font size */
      cursor: pointer; /* Change cursor to pointer on hover */
      margin: 0 20px;
      -webkit-text-stroke: 0.5px;
    }}
  </style>
</head>
<body>
  <div class="mobile">
    <!-- Status bar -->
    <div class="status-bar">
      <div>ETH-MTN</div>
      <div>
        <i class="bi bi-wifi network-icon"></i>
        <span>{now}</span>
        <i class="bi bi-battery battery-icon"></i>
        <span>80%</span>
      </div>
    </div>

    <!-- Icons for the apps -->
    <div class="icon" onclick="alert('Camera icon clicked')"><i class="bi bi-camera"></i></div>
    <div class="icon" onclick="alert('Music icon clicked')"><i class="bi bi-music-note"></i></div>
    <div class="icon" onclick="alert('Chat icon clicked')"><i class="bi bi-chat-dots"></i></div>
    <div class="icon" onclick="alert('Calendar icon clicked')"><i class="bi bi-calendar-event"></i></div>
    <div class="icon" onclick="alert('Basket icon clicked')"><i class="bi bi-basket"></i></div>
    <div class="icon" onclick="alert('Bookmark icon clicked')"><i class="bi bi-bookmark"></i></div>
    <div class="icon" onclick="alert('Brightness icon clicked')"><i class="bi bi-brightness-high"></i></div>
    <div class="icon" onclick="alert('Cash icon clicked')"><i class="bi bi-cash"></i></div>
    <div class="icon" onclick="alert('Cloud icon clicked')"><i class="bi bi-cloud"></i></div>
    <div class="icon" onclick="alert('Envelope icon clicked')"><i class="bi bi-envelope"></i></div>
    <div class="icon" onclick="alert('Globe icon clicked')"><i class="bi bi-globe"></i></div>
    <div class="icon" onclick="alert('Heart icon clicked')"><i class="bi bi-heart"></i></div>
    <div class="icon" onclick="alert('Lightbulb icon clicked')"><i class="bi bi-lightbulb"></i></div>
    <div class="icon" onclick="alert('Moon icon clicked')"><i class="bi bi-moon"></i></div>
    <div class="icon" onclick="alert('Person icon clicked')"><i class="bi bi-person"></i></div>
    <div class="icon" onclick="alert('Piggy bank icon clicked')"><i class="bi bi-piggy-bank"></i></div>
    <div class="icon" onclick="alert('Printer icon clicked')"><i class="bi bi-printer"></i></div>
    <div class="icon" onclick="alert('Telephone icon clicked')"><i class="bi bi-telephone"></i></div>
    <!-- Navigation buttons -->
    <div class="navigation-buttons">
      <button class="btn btn-secondary" onclick="alert('Back button clicked')"><i class="bi bi-caret-left"></i></button>
      <button class="btn btn-secondary" onclick="alert('Home button clicked')"><i class="bi bi-house-door"></i></button>
      <button class="btn btn-secondary" onclick="alert('Recent apps button clicked')"><i class="bi bi-square"></i></button>
    </div>
  </div>
  <!-- Include Bootstrap Icons library -->
  <script src="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.8.1/font/bootstrap-icons.css"></script>
</body>
"""
HTML(emulator)
# Out:
# <head>
#   <title>Mobile Emulator</title>
#   <!-- Include Bootstrap CSS -->
#   <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" />
#
#   <!-- Bootstrap Font Icon CSS -->
#   <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" />
#   <style>
#     body{
#       background-color: #020202;
#     }
#     /* Style the mobile emulator */
#     .mobile {
#       width: 375px; /* Set the width of the mobile screen */
#       height: 667px; /* Set the height of the mobile screen */
#       background-color: #f2f2f2; /* Set the background color */
#       border: 2px solid #ccc; /* Set a border around the mobile */
#       border-radius: 20px; /* Rounded corners */
#       margin: 0 auto; /* Center the mobile emulator */
#       padding-top: 20px;
#       overflow: hidden; /* Hide overflow content */
# ...
